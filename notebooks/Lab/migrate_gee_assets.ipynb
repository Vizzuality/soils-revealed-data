# %% [markdown]
# # GEE assets migration
#
# Notebook to migrate GEE assets from one a legacy project to a new cloud project.

# %% [markdown]
# ## Step 1: Setup
# **Authenticate with Earth Engine:**

# %%
import ee
ee.Authenticate()
ee.Initialize()

# %% [markdown]
# ## Step 2: List Legacy Assets

# %%
def list_assets(path):
    asset_list = ee.data.listAssets({'parent': path})
    return [asset['name'] for asset in asset_list['assets']]

legacy_project = 'projects/earthengine-legacy/assets/projects/soils-revealed'
legacy_assets = list_assets(legacy_project)

# Print and save the asset list
print(legacy_assets)
with open('legacy_assets.txt', 'w') as file:
    file.write('\n'.join(legacy_assets))
# Out:
# ['projects/earthengine-legacy/assets/projects/soils-revealed/ESA_landcover_ipcc', 'projects/earthengine-legacy/assets/projects/soils-revealed/Future', 'projects/earthengine-legacy/assets/projects/soils-revealed/Historic', 'projects/earthengine-legacy/assets/projects/soils-revealed/Recent', 'projects/earthengine-legacy/assets/projects/soils-revealed/experimental-dataset', 'projects/earthengine-legacy/assets/projects/soils-revealed/nlcd_change_2011_20']

# %% [markdown]
# ###  Recursively Map Assets
#
# The following script will traverse all subfolders, image collections, and images in the legacy project and store the structure.

# %%
def map_assets_recursive(asset_path, asset_map=None):
    if asset_map is None:
        asset_map = {}
    
    # List assets at the current path
    assets = ee.data.listAssets({'parent': asset_path})
    
    # Map out each asset
    for asset in assets.get('assets', []):
        asset_type = asset['type']
        asset_name = asset['name']
        
        if asset_type == 'FOLDER':
            # If it's a folder, recursively map its contents
            print(f"Found folder: {asset_name}")
            asset_map[asset_name] = map_assets_recursive(asset_name, {})
        elif asset_type == 'IMAGE_COLLECTION':
            # Map Image Collections
            print(f"Found image collection: {asset_name}")
            asset_map[asset_name] = list_image_collection(asset_name)
        elif asset_type == 'IMAGE':
            # Map Images
            print(f"Found image: {asset_name}")
            asset_map[asset_name] = 'IMAGE'
        else:
            print(f"Skipping unknown type: {asset_type} at {asset_name}")
    
    return asset_map

def list_image_collection(collection_path):
    # List images in an Image Collection
    images = ee.ImageCollection(collection_path).aggregate_array('system:id').getInfo()
    return images

# Map assets in the legacy project
legacy_project = 'projects/earthengine-legacy/assets/projects/soils-revealed'
asset_map = map_assets_recursive(legacy_project)

# Print the asset map
print(asset_map)

# Save to a file
import json
with open('asset_map.json', 'w') as f:
    json.dump(asset_map, f, indent=2)
# Out:
# Found image collection: projects/earthengine-legacy/assets/projects/soils-revealed/ESA_landcover_ipcc
# Found folder: projects/earthengine-legacy/assets/projects/soils-revealed/Future
# Found image collection: projects/earthengine-legacy/assets/projects/soils-revealed/Future/scenario_crop_I_dSOC
# Found image collection: projects/earthengine-legacy/assets/projects/soils-revealed/Future/scenario_crop_MGI_dSOC
# Found image collection: projects/earthengine-legacy/assets/projects/soils-revealed/Future/scenario_crop_MG_dSOC
# Found image collection: projects/earthengine-legacy/assets/projects/soils-revealed/Future/scenario_degradation_ForestToCrop_dSOC
# Found image collection: projects/earthengine-legacy/assets/projects/soils-revealed/Future/scenario_degradation_ForestToGrass_dSOC
# Found image collection: projects/earthengine-legacy/assets/projects/soils-revealed/Future/scenario_degradation_NoDeforestation_dSOC
# Found image collection: projects/earthengine-legacy/assets/projects/soils-revealed/Future/scenario_grass_full_dSOC
# Found image collection: projects/earthengine-legacy/assets/projects/soils-revealed/Future/scenario_grass_part_dSOC
# Found image collection: projects/earthengine-legacy/assets/projects/soils-revealed/Future/scenario_rewilding_dSOC
# Found folder: projects/earthengine-legacy/assets/projects/soils-revealed/Historic
# Found image: projects/earthengine-legacy/assets/projects/soils-revealed/Historic/SOCS_0_100cm_year_2010AD_10km
# Found image: projects/earthengine-legacy/assets/projects/soils-revealed/Historic/SOCS_0_100cm_year_NoLU_10km
# Found image: projects/earthengine-legacy/assets/projects/soils-revealed/Historic/SOCS_0_200cm_year_2010AD_10km
# Found image: projects/earthengine-legacy/assets/projects/soils-revealed/Historic/SOCS_0_200cm_year_NoLU_10km
# Found image: projects/earthengine-legacy/assets/projects/soils-revealed/Historic/SOCS_0_30cm_year_2010AD_10km
# Found image: projects/earthengine-legacy/assets/projects/soils-revealed/Historic/SOCS_0_30cm_year_NoLU_10km
# Found folder: projects/earthengine-legacy/assets/projects/soils-revealed/Recent
# Found image collection: projects/earthengine-legacy/assets/projects/soils-revealed/Recent/SOC_stock_nov2020
# Found image collection: projects/earthengine-legacy/assets/projects/soils-revealed/Recent/SOC_stocks
# Found folder: projects/earthengine-legacy/assets/projects/soils-revealed/experimental-dataset
# Found image collection: projects/earthengine-legacy/assets/projects/soils-revealed/experimental-dataset/SOC_concentration
# Found image collection: projects/earthengine-legacy/assets/projects/soils-revealed/experimental-dataset/SOC_concentration_2020
# Found image collection: projects/earthengine-legacy/assets/projects/soils-revealed/experimental-dataset/SOC_stock
# Found image collection: projects/earthengine-legacy/assets/projects/soils-revealed/experimental-dataset/SOC_stock_0_30
# Found image: projects/earthengine-legacy/assets/projects/soils-revealed/nlcd_change_2011_20
# {'projects/earthengine-legacy/assets/projects/soils-revealed/ESA_landcover_ipcc': ['projects/soils-revealed/ESA_landcover_ipcc/ESA_2000_ipcc', 'projects/soils-revealed/ESA_landcover_ipcc/ESA_2001_ipcc', 'projects/soils-revealed/ESA_landcover_ipcc/ESA_2002_ipcc', 'projects/soils-revealed/ESA_landcover_ipcc/ESA_2003_ipcc', 'projects/soils-revealed/ESA_landcover_ipcc/ESA_2004_ipcc', 'projects/soils-revealed/ESA_landcover_ipcc/ESA_2005_ipcc', 'projects/soils-revealed/ESA_landcover_ipcc/ESA_2006_ipcc', 'projects/soils-revealed/ESA_landcover_ipcc/ESA_2007_ipcc', 'projects/soils-revealed/ESA_landcover_ipcc/ESA_2008_ipcc', 'projects/soils-revealed/ESA_landcover_ipcc/ESA_2009_ipcc', 'projects/soils-revealed/ESA_landcover_ipcc/ESA_2010_ipcc', 'projects/soils-revealed/ESA_landcover_ipcc/ESA_2011_ipcc', 'projects/soils-revealed/ESA_landcover_ipcc/ESA_2012_ipcc', 'projects/soils-revealed/ESA_landcover_ipcc/ESA_2013_ipcc', 'projects/soils-revealed/ESA_landcover_ipcc/ESA_2014_ipcc', 'projects/soils-revealed/ESA_landcover_ipcc/ESA_2015_ipcc', 'projects/soils-revealed/ESA_landcover_ipcc/ESA_2016_ipcc', 'projects/soils-revealed/ESA_landcover_ipcc/ESA_2017_ipcc', 'projects/soils-revealed/ESA_landcover_ipcc/ESA_2018_ipcc'], 'projects/earthengine-legacy/assets/projects/soils-revealed/Future': {'projects/earthengine-legacy/assets/projects/soils-revealed/Future/scenario_crop_I_dSOC': ['projects/soils-revealed/Future/scenario_crop_I_dSOC/scenario_crop_I_dSOC_Y05', 'projects/soils-revealed/Future/scenario_crop_I_dSOC/scenario_crop_I_dSOC_Y10', 'projects/soils-revealed/Future/scenario_crop_I_dSOC/scenario_crop_I_dSOC_Y15', 'projects/soils-revealed/Future/scenario_crop_I_dSOC/scenario_crop_I_dSOC_Y20'], 'projects/earthengine-legacy/assets/projects/soils-revealed/Future/scenario_crop_MGI_dSOC': ['projects/soils-revealed/Future/scenario_crop_MGI_dSOC/scenario_crop_MGI_dSOC_Y05', 'projects/soils-revealed/Future/scenario_crop_MGI_dSOC/scenario_crop_MGI_dSOC_Y10', 'projects/soils-revealed/Future/scenario_crop_MGI_dSOC/scenario_crop_MGI_dSOC_Y15', 'projects/soils-revealed/Future/scenario_crop_MGI_dSOC/scenario_crop_MGI_dSOC_Y20'], 'projects/earthengine-legacy/assets/projects/soils-revealed/Future/scenario_crop_MG_dSOC': ['projects/soils-revealed/Future/scenario_crop_MG_dSOC/scenario_crop_MG_dSOC_Y05', 'projects/soils-revealed/Future/scenario_crop_MG_dSOC/scenario_crop_MG_dSOC_Y10', 'projects/soils-revealed/Future/scenario_crop_MG_dSOC/scenario_crop_MG_dSOC_Y15', 'projects/soils-revealed/Future/scenario_crop_MG_dSOC/scenario_crop_MG_dSOC_Y20'], 'projects/earthengine-legacy/assets/projects/soils-revealed/Future/scenario_degradation_ForestToCrop_dSOC': ['projects/soils-revealed/Future/scenario_degradation_ForestToCrop_dSOC/scenario_degradation_ForestToCrop_dSOC_Y05', 'projects/soils-revealed/Future/scenario_degradation_ForestToCrop_dSOC/scenario_degradation_ForestToCrop_dSOC_Y10', 'projects/soils-revealed/Future/scenario_degradation_ForestToCrop_dSOC/scenario_degradation_ForestToCrop_dSOC_Y15', 'projects/soils-revealed/Future/scenario_degradation_ForestToCrop_dSOC/scenario_degradation_ForestToCrop_dSOC_Y20'], 'projects/earthengine-legacy/assets/projects/soils-revealed/Future/scenario_degradation_ForestToGrass_dSOC': ['projects/soils-revealed/Future/scenario_degradation_ForestToGrass_dSOC/scenario_degradation_ForestToGrass_dSOC_Y05', 'projects/soils-revealed/Future/scenario_degradation_ForestToGrass_dSOC/scenario_degradation_ForestToGrass_dSOC_Y10', 'projects/soils-revealed/Future/scenario_degradation_ForestToGrass_dSOC/scenario_degradation_ForestToGrass_dSOC_Y15', 'projects/soils-revealed/Future/scenario_degradation_ForestToGrass_dSOC/scenario_degradation_ForestToGrass_dSOC_Y20'], 'projects/earthengine-legacy/assets/projects/soils-revealed/Future/scenario_degradation_NoDeforestation_dSOC': ['projects/soils-revealed/Future/scenario_degradation_NoDeforestation_dSOC/scenario_degradation_NoDeforestation_dSOC_Y05', 'projects/soils-revealed/Future/scenario_degradation ...

# %% [markdown]
# ## Step 3: Replicate the Structure in the Cloud Project
# The following script uses the asset map to recreate the structure in your cloud projec

# %%
def create_asset_structure(asset_map, source_project, destination_project):
    for asset, content in asset_map.items():
        # Determine source and destination paths
        source_path = asset
        destination_path = asset.replace(f'{source_project}/', f'{destination_project}/')
        
        if isinstance(content, dict):  # It's a folder
            print(f"Creating folder: {destination_path}")
            try:
                ee.data.createFolder(destination_path)
            except Exception as e:
                print(f"Error creating folder {destination_path}: {e}")
            # Recur into the folder
            create_asset_structure(content, source_project, destination_project)
        elif isinstance(content, list):  # It's an Image Collection
            print(f"Creating image collection: {destination_path}")
            try:
                ee.data.createAsset({'type': 'IMAGE_COLLECTION'}, destination_path)
            except Exception as e:
                print(f"Error creating collection {destination_path}: {e}")
            # Copy each image in the collection
            for image in content:
                dest_image_path = image.replace('projects/soils-revealed/', f'{destination_project}/')
                try:
                    print(f"Copying image: {image} to {dest_image_path}")
                    if image != dest_image_path:  # Avoid self-copying
                        ee.data.copyAsset(image, dest_image_path)
                    else:
                        print(f"Skipped copying {image} to itself.")
                except Exception as e:
                    print(f"Error copying image {image}: {e}")
        elif content == 'IMAGE':  # It's an individual image
            destination_path = source_path.replace('projects/soils-revealed/', f'{destination_project}/')
            print(f"Copying image: {source_path} to {destination_path}")
            try:
                if source_path != destination_path:  # Avoid self-copying
                    ee.data.copyAsset(source_path, destination_path)
                else:
                    print(f"Skipped copying {source_path} to itself.")
            except Exception as e:
                print(f"Error copying image {source_path}: {e}")
                
# Define source and destination projects
source_project = 'projects/earthengine-legacy/assets/projects/soils-revealed'
destination_project = 'projects/soils-revealed-307010/assets'

# Replicate the structure
create_asset_structure(asset_map, source_project, destination_project)
# Out:
# Creating image collection: projects/soils-revealed-307010/assets/ESA_landcover_ipcc
# Error creating collection projects/soils-revealed-307010/assets/ESA_landcover_ipcc: Cannot overwrite asset 'projects/soils-revealed-307010/assets/ESA_landcover_ipcc'.
# Copying image: projects/soils-revealed/ESA_landcover_ipcc/ESA_2000_ipcc to projects/soils-revealed-307010/assets/ESA_landcover_ipcc/ESA_2000_ipcc
# Copying image: projects/soils-revealed/ESA_landcover_ipcc/ESA_2001_ipcc to projects/soils-revealed-307010/assets/ESA_landcover_ipcc/ESA_2001_ipcc
# Copying image: projects/soils-revealed/ESA_landcover_ipcc/ESA_2002_ipcc to projects/soils-revealed-307010/assets/ESA_landcover_ipcc/ESA_2002_ipcc
# Copying image: projects/soils-revealed/ESA_landcover_ipcc/ESA_2003_ipcc to projects/soils-revealed-307010/assets/ESA_landcover_ipcc/ESA_2003_ipcc
# Copying image: projects/soils-revealed/ESA_landcover_ipcc/ESA_2004_ipcc to projects/soils-revealed-307010/assets/ESA_landcover_ipcc/ESA_2004_ipcc
# Copying image: projects/soils-revealed/ESA_landcover_ipcc/ESA_2005_ipcc to projects/soils-revealed-307010/assets/ESA_landcover_ipcc/ESA_2005_ipcc
# Copying image: projects/soils-revealed/ESA_landcover_ipcc/ESA_2006_ipcc to projects/soils-revealed-307010/assets/ESA_landcover_ipcc/ESA_2006_ipcc
# Copying image: projects/soils-revealed/ESA_landcover_ipcc/ESA_2007_ipcc to projects/soils-revealed-307010/assets/ESA_landcover_ipcc/ESA_2007_ipcc
# Copying image: projects/soils-revealed/ESA_landcover_ipcc/ESA_2008_ipcc to projects/soils-revealed-307010/assets/ESA_landcover_ipcc/ESA_2008_ipcc
# Copying image: projects/soils-revealed/ESA_landcover_ipcc/ESA_2009_ipcc to projects/soils-revealed-307010/assets/ESA_landcover_ipcc/ESA_2009_ipcc
# Copying image: projects/soils-revealed/ESA_landcover_ipcc/ESA_2010_ipcc to projects/soils-revealed-307010/assets/ESA_landcover_ipcc/ESA_2010_ipcc
# Copying image: projects/soils-revealed/ESA_landcover_ipcc/ESA_2011_ipcc to projects/soils-revealed-307010/assets/ESA_landcover_ipcc/ESA_2011_ipcc
# Copying image: projects/soils-revealed/ESA_landcover_ipcc/ESA_2012_ipcc to projects/soils-revealed-307010/assets/ESA_landcover_ipcc/ESA_2012_ipcc
# Copying image: projects/soils-revealed/ESA_landcover_ipcc/ESA_2013_ipcc to projects/soils-revealed-307010/assets/ESA_landcover_ipcc/ESA_2013_ipcc
# Copying image: projects/soils-revealed/ESA_landcover_ipcc/ESA_2014_ipcc to projects/soils-revealed-307010/assets/ESA_landcover_ipcc/ESA_2014_ipcc
# Copying image: projects/soils-revealed/ESA_landcover_ipcc/ESA_2015_ipcc to projects/soils-revealed-307010/assets/ESA_landcover_ipcc/ESA_2015_ipcc
# Copying image: projects/soils-revealed/ESA_landcover_ipcc/ESA_2016_ipcc to projects/soils-revealed-307010/assets/ESA_landcover_ipcc/ESA_2016_ipcc
# Copying image: projects/soils-revealed/ESA_landcover_ipcc/ESA_2017_ipcc to projects/soils-revealed-307010/assets/ESA_landcover_ipcc/ESA_2017_ipcc
# Copying image: projects/soils-revealed/ESA_landcover_ipcc/ESA_2018_ipcc to projects/soils-revealed-307010/assets/ESA_landcover_ipcc/ESA_2018_ipcc
# Creating folder: projects/soils-revealed-307010/assets/Future
# Error creating folder projects/soils-revealed-307010/assets/Future: Cannot overwrite asset 'projects/soils-revealed-307010/assets/Future'.
# Creating image collection: projects/soils-revealed-307010/assets/Future/scenario_crop_I_dSOC
# Error creating collection projects/soils-revealed-307010/assets/Future/scenario_crop_I_dSOC: Cannot overwrite asset 'projects/soils-revealed-307010/assets/Future/scenario_crop_I_dSOC'.
# Copying image: projects/soils-revealed/Future/scenario_crop_I_dSOC/scenario_crop_I_dSOC_Y05 to projects/soils-revealed-307010/assets/Future/scenario_crop_I_dSOC/scenario_crop_I_dSOC_Y05
# Copying image: projects/soils-revealed/Future/scenario_crop_I_dSOC/scenario_crop_I_dSOC_Y10 to projects/soils-revealed-307010/assets/Future/scenario_crop_I_dSOC/scenario_crop_I_dSOC_Y10
# Copying image: projects/soils-revealed/Future/scenario_crop_I_dSOC/scenario_crop_I_dSOC_Y15 to projects/soils-revealed-307010/assets/Future/scenario_crop_I_dSOC/scenario_crop_I_dSOC_Y15
# Copying image: projects/soils-revealed/Future/scenario_crop_I_dSOC/scenario_crop_I_dSOC_Y20 to projects/soils-revealed-307010/assets/Future/scenario_crop_I_dSOC/scenario_crop_I_dSOC_Y20
# Creating image collection: projects/soils-revealed-307010/assets/Future/scenario_crop_MGI_dSOC
# Error creating collection projects/soils-revealed-307010/assets/Future/scenario_crop_MGI_dSOC: Cannot overwrite asset 'projects/soils-revealed-307010/assets/Future/scenario_crop_MGI_dSOC'.
# Copying image: projects/soils-revealed/Future/scenario_crop_MGI_dSOC/scenario_crop_MGI_dSOC_Y05 to projects/soils-revealed-307010/assets/Future/scenario_crop_MGI_dSOC/scenario_crop_MGI_dSOC_Y05
# Copying image: projects/soils-revealed/Future/scenario_crop_MGI_dSOC/scenario_crop_MGI_dSOC_Y10 to projects/soils-revealed-307010/assets/Future/scenario_crop_MGI_dSOC/scenario_crop_MGI_dSOC_Y10
# Copying image: projects/soils-revealed/Future/scenario_crop_MGI_dSOC/scenario_crop_MGI_dSOC_Y15 to projects/soils-revealed-307010/assets/Future/scenario_crop_MGI_dSOC/scenario_crop_MGI_dSOC_Y15
# Copying image: projects/soils-revealed/Future/scenario_crop_MGI_dSOC/scenario_crop_MGI_dSOC_Y20 to projects/soils-revealed-307010/assets/Future/scenario_crop_MGI_dSOC/scenario_crop_MGI_dSOC_Y20
# Creating image collection: projects/soils-revealed-307010/assets/Future/scenario_crop_MG_dSOC
# Error creating collection projects/soils-revealed-307010/assets/Future/scenario_crop_MG_dSOC: Cannot overwrite asset 'projects/soils-revealed-307010/assets/Future/scenario_crop_MG_dSOC'.
# Copying image: projects/soils-revealed/Future/scenario_crop_MG_dSOC/scenario_crop_MG_dSOC_Y05 to projects/soils-revealed-307010/assets/Future/scenario_crop_MG_dSOC/scenario_crop_MG_dSOC_Y05
# Copying image: projects/soils-revealed/Future/scenario_crop_MG_dSOC/scenario_crop_MG_dSOC_Y10 to projects/soils-revealed-307010/assets/Future/scenario_crop_MG_dSOC/scenario_crop_MG_dSOC_Y10
# Copying image: projects/soils-revealed/Future/scenario_crop_MG_dSOC/scenario_crop_MG_dSOC_Y15 to projects/soils-revealed-307010/assets/Future/scenario_crop_MG_dSOC/scenario_crop_MG_dSOC_Y15
# Copying image: projects/soils-revealed/Future/scenario_crop_MG_dSOC/scenario_crop_MG_dSOC_Y20 to projects/soils-revealed-307010/assets/Future/scenario_crop_MG_dSOC/scenario_crop_MG_dSOC_Y20
# Creating image collection: projects/soils-revealed-307010/assets/Future/scenario_degradation_ForestToCrop_dSOC
# Error creating collection projects/soils-revealed-307010/assets/Future/scenario_degradation_ForestToCrop_dSOC: Cannot overwrite asset 'projects/soils-revealed-307010/assets/Future/scenario_degradation_ForestToCrop_dSOC'.
# Copying image: projects/soils-revealed/Future/scenario_degradation_ForestToCrop_dSOC/scenario_degradation_ForestToCrop_dSOC_Y05 to projects/soils-revealed-307010/assets/Future/scenario_degradation_ForestToCrop_dSOC/scenario_degradation_ForestToCrop_dSOC_Y05
# Copying image: projects/soils-revealed/Future/scenario_degradation_ForestToCrop_dSOC/scenario_degradation_ForestToCrop_dSOC_Y10 to projects/soils-revealed-307010/assets/Future/scenario_degradation_ForestToCrop_dSOC/scenario_degradation_ForestToCrop_dSOC_Y10
# Copying image: projects/soils-revealed/Future/scenario_degradation_ForestToCrop_dSOC/scenario_degradation_ForestToCrop_dSOC_Y15 to projects/soils-revealed-307010/assets/Future/scenario_degradation_ForestToCrop_dSOC/scenario_degradation_ForestToCrop_dSOC_Y15
# Copying image: projects/soils-revealed/Future/scenario_degradation_ForestToCrop_dSOC/scenario_degradation_ForestToCrop_dSOC_Y20 to projects/soils-revealed-307010/assets/Future/scenario_degradation_ForestToCrop_dSOC/scenario_degradation_ForestToCrop_dSOC_Y20
# Creating image collection: projects/soils-revealed-307010/assets/Future/scenario_degradation_ForestToGrass_dSOC
# Error creating collection projects/soils-revealed-307010/assets/Future/scenario_degradation_ForestToGrass_dSOC: Cannot overwrite asset 'projects/soils-revealed-307010/assets/Future/scenario_degradation_ForestToGrass_dSOC'.
# Copying image: projects/soils-revealed/Future/scenario_degradation_ForestToGrass_dSOC/scenario_degradation_ForestToGrass_dSOC_Y05 to projects/soils-revealed-307010/assets/Future/scenario_degradation_ForestToGrass_dSOC/scenario_degradation_ForestToGrass_dSOC_Y05
# Copying image: projects/soils-revealed/Future/scenario_degradation_ForestToGrass_dSOC/scenario_degradation_ForestToGrass_dSOC_Y10 to projects/soils-revealed-307010/assets/Future/scenario_degradation_ForestToGrass_dSOC/scenario_degradation_ForestToGrass_dSOC_Y10
# Copying image: projects/soils-revealed/Future/scenario_degradation_ForestToGrass_dSOC/scenario_degradation_ForestToGrass_dSOC_Y15 to projects/soils-revealed-307010/assets/Future/scenario_degradation_ForestToGrass_dSOC/scenario_degradation_ForestToGrass_dSOC_Y15
# Copying image: projects/soils-revealed/Future/scenario_degradation_ForestToGrass_dSOC/scenario_degradation_ForestToGrass_dSOC_Y20 to projects/soils-revealed-307010/assets/Future/scenario_degradation_ForestToGrass_dSOC/scenario_degradation_ForestToGrass_dSOC_Y20
# Creating image collection: projects/soils-revealed-307010/assets/Future/scenario_degradation_NoDeforestation_dSOC
# Error creating collection projects/soils-revealed-307010/assets/Future/scenario_degradation_NoDeforestation_dSOC: Cannot overwrite asset 'projects/soils-revealed-307010/assets/Future/scenario_degradation_NoDeforestation_dSOC'.
# Copying image: projects/soils-revealed/Future/scenario_degradation_NoDeforestation_dSOC/scenario_degradation_NoDeforestation_dSOC_Y05 to projects/soils-revealed-307010/assets/Future/scenario_degradation_NoDeforestation_dSOC/scenario_degradation_NoDeforestation_dSOC_Y05
# Copying image: projects/soils-revealed/Future/scenario_degradation_NoDeforestation_dSOC/scenario_degradation_NoDeforestation_dSOC_Y10 to projects/soils-revealed-307010/assets/Future/scenario_degradation_NoDeforestation_dSOC/scenario_degradation_NoDeforestation_dSOC_Y10
# Copying image: projects/soils-revealed/Future/scenario_degradation_NoDeforestation_dSOC/scenario_degradation_NoDeforestation_dSOC_Y15 to projects/soils-revealed-307010/assets/Future/scenario_degradation_NoDeforestation_dSOC/scenario_degradation_NoDeforestation_dSOC_Y15
# Copying image: projects/soils-revealed/Future/scenario_degradation_NoDeforestation_dSOC/scenario_degradation_NoDeforestation_dSOC_Y20 to projects/soils-revealed-307010/assets/Future/scenario_degradation_NoDeforestation_dSOC/scenario_degradation_NoDeforestation_dSOC_Y20
# Creating image collection: projects/soils-revealed-307010/assets/Future/scenario_grass_full_dSOC
# Error creating collection projects/soils-revealed-307010/assets/Future/scenario_grass_full_dSOC: Cannot overwrite asset 'projects/soils-revealed-307010/assets/Future/scenario_grass_full_dSOC'.
# Copying image: projects/soils-revealed/Future/scenario_grass_full_dSOC/scenario_grass_full_dSOC_Y05 to projects/soils-revealed-307010/assets/Future/scenario_grass_full_dSOC/scenario_grass_full_dSOC_Y05
# Copying image: projects/soils-revealed/Future/scenario_grass_full_dSOC/scenario_grass_full_dSOC_Y10 to projects/soils-revealed-307010/assets/Future/scenario_grass_full_dSOC/scenario_grass_full_dSOC_Y10
# Copying image: projects/soils-revealed/Future/scenario_grass_full_dSOC/scenario_grass_full_dSOC_Y15 to projects/soils-revealed-307010/assets/Future/scenario_grass_full_dSOC/scenario_grass_full_dSOC_Y15
# Copying image: projects/soils-revealed/Future/scenario_grass_full_dSOC/scenario_grass_full_dSOC_Y20 to projects/soils-revealed-307010/assets/Future/scenario_grass_full_dSOC/scenario_grass_full_dSOC_Y20
# Creating image collection: projects/soils-revealed-307010/assets/Future/scenario_grass_part_dSOC
# Error creating collection projects/soils-revealed-307010/assets/Future/scenario_grass_part_dSOC: Cannot overwrite asset 'projects/soils-revealed-307010/assets/Future/scenario_grass_part_dSOC'.
# Copying image: projects/soils-revealed/Future/scenario_grass_part_dSOC/scenario_grass_part_dSOC_Y05 to projects/soils-revealed-307010/assets/Future/scenario_grass_part_dSOC/scenario_grass_part_dSOC_Y05
# Copying image: projects/soils-revealed/Future/scenario_grass_part_dSOC/scenario_grass_part_dSOC_Y10 to projects/soils-revealed-307010/assets/Future/scenario_grass_part_dSOC/scenario_grass_part_dSOC_Y10
# Copying image: projects/soils-revealed/Future/scenario_grass_part_dSOC/scenario_grass_part_dSOC_Y15 to projects/soils-revealed-307010/assets/Future/scenario_grass_part_dSOC/scenario_grass_part_dSOC_Y15
# Copying image: projects/soils-revealed/Future/scenario_grass_part_dSOC/scenario_grass_part_dSOC_Y20 to projects/soils-revealed-307010/assets/Future/scenario_grass_part_dSOC/scenario_grass_part_dSOC_Y20
# Creating image collection: projects/soils-revealed-307010/assets/Future/scenario_rewilding_dSOC
# Error creating collection projects/soils-revealed-307010/assets/Future/scenario_rewilding_dSOC: Cannot overwrite asset 'projects/soils-revealed-307010/assets/Future/scenario_rewilding_dSOC'.
# Copying image: projects/soils-revealed/Future/scenario_rewilding_dSOC/scenario_rewilding_dSOC_Y05 to projects/soils-revealed-307010/assets/Future/scenario_rewilding_dSOC/scenario_rewilding_dSOC_Y05
# Copying image: projects/soils-revealed/Future/scenario_rewilding_dSOC/scenario_rewilding_dSOC_Y10 to projects/soils-revealed-307010/assets/Future/scenario_rewilding_dSOC/scenario_rewilding_dSOC_Y10
# Copying image: projects/soils-revealed/Future/scenario_rewilding_dSOC/scenario_rewilding_dSOC_Y15 to projects/soils-revealed-307010/assets/Future/scenario_rewilding_dSOC/scenario_rewilding_dSOC_Y15
# Copying image: projects/soils-revealed/Future/scenario_rewilding_dSOC/scenario_rewilding_dSOC_Y20 to projects/soils-revealed-307010/assets/Future/scenario_rewilding_dSOC/scenario_rewilding_dSOC_Y20
# Creating folder: projects/soils-revealed-307010/assets/Historic
# Error creating folder projects/soils-revealed-307010/assets/Historic: Cannot overwrite asset 'projects/soils-revealed-307010/assets/Historic'.
# Copying image: projects/earthengine-legacy/assets/projects/soils-revealed/Historic/SOCS_0_100cm_year_2010AD_10km to projects/earthengine-legacy/assets/projects/soils-revealed-307010/assets/Historic/SOCS_0_100cm_year_2010AD_10km
# Error copying image projects/earthengine-legacy/assets/projects/soils-revealed/Historic/SOCS_0_100cm_year_2010AD_10km: Asset 'projects/earthengine-legacy/assets/projects/soils-revealed-307010/assets/Historic' does not exist or doesn't allow this operation.
# Copying image: projects/earthengine-legacy/assets/projects/soils-revealed/Historic/SOCS_0_100cm_year_NoLU_10km to projects/earthengine-legacy/assets/projects/soils-revealed-307010/assets/Historic/SOCS_0_100cm_year_NoLU_10km
# Error copying image projects/earthengine-legacy/assets/projects/soils-revealed/Historic/SOCS_0_100cm_year_NoLU_10km: Asset 'projects/earthengine-legacy/assets/projects/soils-revealed-307010/assets/Historic' does not exist or doesn't allow this operation.
# Copying image: projects/earthengine-legacy/assets/projects/soils-revealed/Historic/SOCS_0_200cm_year_2010AD_10km to projects/earthengine-legacy/assets/projects/soils-revealed-307010/assets/Historic/SOCS_0_200cm_year_2010AD_10km
# Error copying image projects/earthengine-legacy/assets/projects/soils-revealed/Historic/SOCS_0_200cm_year_2010AD_10km: Asset 'projects/earthengine-legacy/assets/projects/soils-revealed-307010/assets/Historic' does not exist or doesn't allow this operation.
# Copying image: projects/earthengine-legacy/assets/projects/soils-revealed/Historic/SOCS_0_200cm_year_NoLU_10km to projects/earthengine-legacy/assets/projects/soils-revealed-307010/assets/Historic/SOCS_0_200cm_year_NoLU_10km
# Error copying image projects/earthengine-legacy/assets/projects/soils-revealed/Historic/SOCS_0_200cm_year_NoLU_10km: Asset 'projects/earthengine-legacy/assets/projects/soils-revealed-307010/assets/Historic' does not exist or doesn't allow this operation.
# Copying image: projects/earthengine-legacy/assets/projects/soils-revealed/Historic/SOCS_0_30cm_year_2010AD_10km to projects/earthengine-legacy/assets/projects/soils-revealed-307010/assets/Historic/SOCS_0_30cm_year_2010AD_10km
# Error copying image projects/earthengine-legacy/assets/projects/soils-revealed/Historic/SOCS_0_30cm_year_2010AD_10km: Asset 'projects/earthengine-legacy/assets/projects/soils-revealed-307010/assets/Historic' does not exist or doesn't allow this operation.
# Copying image: projects/earthengine-legacy/assets/projects/soils-revealed/Historic/SOCS_0_30cm_year_NoLU_10km to projects/earthengine-legacy/assets/projects/soils-revealed-307010/assets/Historic/SOCS_0_30cm_year_NoLU_10km
# Error copying image projects/earthengine-legacy/assets/projects/soils-revealed/Historic/SOCS_0_30cm_year_NoLU_10km: Asset 'projects/earthengine-legacy/assets/projects/soils-revealed-307010/assets/Historic' does not exist or doesn't allow this operation.
# Creating folder: projects/soils-revealed-307010/assets/Recent
# Error creating folder projects/soils-revealed-307010/assets/Recent: Cannot overwrite asset 'projects/soils-revealed-307010/assets/Recent'.
# Creating image collection: projects/soils-revealed-307010/assets/Recent/SOC_stock_nov2020
# Error creating collection projects/soils-revealed-307010/assets/Recent/SOC_stock_nov2020: Cannot overwrite asset 'projects/soils-revealed-307010/assets/Recent/SOC_stock_nov2020'.
# Copying image: projects/soils-revealed/Recent/SOC_stock_nov2020/SOC_stock_2000 to projects/soils-revealed-307010/assets/Recent/SOC_stock_nov2020/SOC_stock_2000
# Copying image: projects/soils-revealed/Recent/SOC_stock_nov2020/SOC_stock_2001 to projects/soils-revealed-307010/assets/Recent/SOC_stock_nov2020/SOC_stock_2001
# Copying image: projects/soils-revealed/Recent/SOC_stock_nov2020/SOC_stock_2002 to projects/soils-revealed-307010/assets/Recent/SOC_stock_nov2020/SOC_stock_2002
# Copying image: projects/soils-revealed/Recent/SOC_stock_nov2020/SOC_stock_2003 to projects/soils-revealed-307010/assets/Recent/SOC_stock_nov2020/SOC_stock_2003
# Copying image: projects/soils-revealed/Recent/SOC_stock_nov2020/SOC_stock_2004 to projects/soils-revealed-307010/assets/Recent/SOC_stock_nov2020/SOC_stock_2004
# Copying image: projects/soils-revealed/Recent/SOC_stock_nov2020/SOC_stock_2005 to projects/soils-revealed-307010/assets/Recent/SOC_stock_nov2020/SOC_stock_2005
# Copying image: projects/soils-revealed/Recent/SOC_stock_nov2020/SOC_stock_2006 to projects/soils-revealed-307010/assets/Recent/SOC_stock_nov2020/SOC_stock_2006
# Copying image: projects/soils-revealed/Recent/SOC_stock_nov2020/SOC_stock_2007 to projects/soils-revealed-307010/assets/Recent/SOC_stock_nov2020/SOC_stock_2007
# Copying image: projects/soils-revealed/Recent/SOC_stock_nov2020/SOC_stock_2008 to projects/soils-revealed-307010/assets/Recent/SOC_stock_nov2020/SOC_stock_2008
# Copying image: projects/soils-revealed/Recent/SOC_stock_nov2020/SOC_stock_2009 to projects/soils-revealed-307010/assets/Recent/SOC_stock_nov2020/SOC_stock_2009
# Copying image: projects/soils-revealed/Recent/SOC_stock_nov2020/SOC_stock_2010 to projects/soils-revealed-307010/assets/Recent/SOC_stock_nov2020/SOC_stock_2010
# Copying image: projects/soils-revealed/Recent/SOC_stock_nov2020/SOC_stock_2011 to projects/soils-revealed-307010/assets/Recent/SOC_stock_nov2020/SOC_stock_2011
# Copying image: projects/soils-revealed/Recent/SOC_stock_nov2020/SOC_stock_2012 to projects/soils-revealed-307010/assets/Recent/SOC_stock_nov2020/SOC_stock_2012
# Copying image: projects/soils-revealed/Recent/SOC_stock_nov2020/SOC_stock_2013 to projects/soils-revealed-307010/assets/Recent/SOC_stock_nov2020/SOC_stock_2013
# Copying image: projects/soils-revealed/Recent/SOC_stock_nov2020/SOC_stock_2014 to projects/soils-revealed-307010/assets/Recent/SOC_stock_nov2020/SOC_stock_2014
# Copying image: projects/soils-revealed/Recent/SOC_stock_nov2020/SOC_stock_2015 to projects/soils-revealed-307010/assets/Recent/SOC_stock_nov2020/SOC_stock_2015
# Copying image: projects/soils-revealed/Recent/SOC_stock_nov2020/SOC_stock_2016 to projects/soils-revealed-307010/assets/Recent/SOC_stock_nov2020/SOC_stock_2016
# Copying image: projects/soils-revealed/Recent/SOC_stock_nov2020/SOC_stock_2017 to projects/soils-revealed-307010/assets/Recent/SOC_stock_nov2020/SOC_stock_2017
# Copying image: projects/soils-revealed/Recent/SOC_stock_nov2020/SOC_stock_2018 to projects/soils-revealed-307010/assets/Recent/SOC_stock_nov2020/SOC_stock_2018
# Creating image collection: projects/soils-revealed-307010/assets/Recent/SOC_stocks
# Error creating collection projects/soils-revealed-307010/assets/Recent/SOC_stocks: Cannot overwrite asset 'projects/soils-revealed-307010/assets/Recent/SOC_stocks'.
# Copying image: projects/soils-revealed/Recent/SOC_stocks/SOC_stocks_2000 to projects/soils-revealed-307010/assets/Recent/SOC_stocks/SOC_stocks_2000
# Copying image: projects/soils-revealed/Recent/SOC_stocks/SOC_stocks_2001 to projects/soils-revealed-307010/assets/Recent/SOC_stocks/SOC_stocks_2001
# Copying image: projects/soils-revealed/Recent/SOC_stocks/SOC_stocks_2002 to projects/soils-revealed-307010/assets/Recent/SOC_stocks/SOC_stocks_2002
# Copying image: projects/soils-revealed/Recent/SOC_stocks/SOC_stocks_2003 to projects/soils-revealed-307010/assets/Recent/SOC_stocks/SOC_stocks_2003
# Copying image: projects/soils-revealed/Recent/SOC_stocks/SOC_stocks_2004 to projects/soils-revealed-307010/assets/Recent/SOC_stocks/SOC_stocks_2004
# Copying image: projects/soils-revealed/Recent/SOC_stocks/SOC_stocks_2005 to projects/soils-revealed-307010/assets/Recent/SOC_stocks/SOC_stocks_2005
# Copying image: projects/soils-revealed/Recent/SOC_stocks/SOC_stocks_2006 to projects/soils-revealed-307010/assets/Recent/SOC_stocks/SOC_stocks_2006
# Copying image: projects/soils-revealed/Recent/SOC_stocks/SOC_stocks_2007 to projects/soils-revealed-307010/assets/Recent/SOC_stocks/SOC_stocks_2007
# Copying image: projects/soils-revealed/Recent/SOC_stocks/SOC_stocks_2008 to projects/soils-revealed-307010/assets/Recent/SOC_stocks/SOC_stocks_2008
# Copying image: projects/soils-revealed/Recent/SOC_stocks/SOC_stocks_2009 to projects/soils-revealed-307010/assets/Recent/SOC_stocks/SOC_stocks_2009
# Copying image: projects/soils-revealed/Recent/SOC_stocks/SOC_stocks_2010 to projects/soils-revealed-307010/assets/Recent/SOC_stocks/SOC_stocks_2010
# Copying image: projects/soils-revealed/Recent/SOC_stocks/SOC_stocks_2011 to projects/soils-revealed-307010/assets/Recent/SOC_stocks/SOC_stocks_2011
# Copying image: projects/soils-revealed/Recent/SOC_stocks/SOC_stocks_2012 to projects/soils-revealed-307010/assets/Recent/SOC_stocks/SOC_stocks_2012
# Copying image: projects/soils-revealed/Recent/SOC_stocks/SOC_stocks_2013 to projects/soils-revealed-307010/assets/Recent/SOC_stocks/SOC_stocks_2013
# Copying image: projects/soils-revealed/Recent/SOC_stocks/SOC_stocks_2014 to projects/soils-revealed-307010/assets/Recent/SOC_stocks/SOC_stocks_2014
# Copying image: projects/soils-revealed/Recent/SOC_stocks/SOC_stocks_2015 to projects/soils-revealed-307010/assets/Recent/SOC_stocks/SOC_stocks_2015
# Copying image: projects/soils-revealed/Recent/SOC_stocks/SOC_stocks_2016 to projects/soils-revealed-307010/assets/Recent/SOC_stocks/SOC_stocks_2016
# Copying image: projects/soils-revealed/Recent/SOC_stocks/SOC_stocks_2017 to projects/soils-revealed-307010/assets/Recent/SOC_stocks/SOC_stocks_2017
# Copying image: projects/soils-revealed/Recent/SOC_stocks/SOC_stocks_2018 to projects/soils-revealed-307010/assets/Recent/SOC_stocks/SOC_stocks_2018
# Creating folder: projects/soils-revealed-307010/assets/experimental-dataset
# Error creating folder projects/soils-revealed-307010/assets/experimental-dataset: Cannot overwrite asset 'projects/soils-revealed-307010/assets/experimental-dataset'.
# Creating image collection: projects/soils-revealed-307010/assets/experimental-dataset/SOC_concentration
# Error creating collection projects/soils-revealed-307010/assets/experimental-dataset/SOC_concentration: Cannot overwrite asset 'projects/soils-revealed-307010/assets/experimental-dataset/SOC_concentration'.
# Copying image: projects/soils-revealed/experimental-dataset/SOC_concentration/SOC_concentration_1982 to projects/soils-revealed-307010/assets/experimental-dataset/SOC_concentration/SOC_concentration_1982
# Copying image: projects/soils-revealed/experimental-dataset/SOC_concentration/SOC_concentration_1983 to projects/soils-revealed-307010/assets/experimental-dataset/SOC_concentration/SOC_concentration_1983
# Copying image: projects/soils-revealed/experimental-dataset/SOC_concentration/SOC_concentration_1984 to projects/soils-revealed-307010/assets/experimental-dataset/SOC_concentration/SOC_concentration_1984
# Copying image: projects/soils-revealed/experimental-dataset/SOC_concentration/SOC_concentration_1985 to projects/soils-revealed-307010/assets/experimental-dataset/SOC_concentration/SOC_concentration_1985
# Copying image: projects/soils-revealed/experimental-dataset/SOC_concentration/SOC_concentration_