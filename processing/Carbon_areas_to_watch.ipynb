# %% [markdown]
# # Carbon areas to watch
# Analysis for precomputing the carbon areas to watchfeature
#
# - http://patrickgray.me/open-geo-tutorial/chapter_7_earth_engine_oceanography.html
# - http://www.acgeospatial.co.uk/cog-part-2-python/
# - http://www.acgeospatial.co.uk/simple-plotting/
# - https://github.com/isciences/exactextract
# - https://github.com/Vizzuality/copernicus-climate-data

# %%
import numpy as np 
import geopandas as gpd
import rasterio

# %% [markdown]
# **Argentina admin 1**

# %%
df = gpd.read_file('../data/gadm36_ARG_shp/gadm36_ARG_1.shp')
df['type'] = df['geometry'].apply(lambda x: x.type)
df['centroid'] = df['geometry'].apply(lambda x: x.centroid)
df.head()
# Out:
#   GID_0     NAME_0    GID_1                  NAME_1  \
# 0   ARG  Argentina  ARG.1_1            Buenos Aires
# 1   ARG  Argentina  ARG.2_1               Catamarca
# 2   ARG  Argentina  ARG.3_1                   Chaco
# 3   ARG  Argentina  ARG.4_1                  Chubut
# 4   ARG  Argentina  ARG.5_1  Ciudad de Buenos Aires
#
#                                            VARNAME_1 NL_NAME_1  \
# 0                                Baires|Buenos Ayres      None
# 1                                               None      None
# 2                     El Chaco|Presidente Juan Peron      None
# 3                                               None      None
# 4  BUENOS AIRES D.F.|Capital Federal|Distretto Fe...      None
#
#              TYPE_1         ENGTYPE_1  CC_1 HASC_1  \
# 0         Provincia          Province  None  AR.BA
# 1         Provincia          Province  None  AR.CT
# 2         Provincia          Province  None  AR.CC
# 3         Provincia          Province  None  AR.CH
# ...

# %%
years = (np.arange(36)+1982).astype(np.str)
base_url = 'https://storage.googleapis.com/vizz-data-transfer/SOC_maps/SOC_stock/'
prefix = 'Feb19_cstocks_'
suffix = '_030_ll.tif'

# %%
year = '2010'
with rasterio.open(base_url+prefix+year+suffix) as dataset:
    profile = dataset.profile
    num_bands = dataset.count
    image = dataset.read()
